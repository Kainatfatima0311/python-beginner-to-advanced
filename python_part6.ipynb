# %% [markdown]
# ##**Python Sets**
#
# A set is a collection which is unordered, unchangeable*, and unindexed.

# %%
set1={"kf","sara","mishal"}
print(set1)

thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'mishal', 'kf', 'sara'}
# {'apple', 'cherry', 'banana'}

# %% [markdown]
# ###Set Items
# Set items are unordered, unchangeable, and do not allow duplicate values

# %% [markdown]
# ###Duplicates Not Allowed

# %%
thisset = {"apple", "banana", "cherry", "apple"}

print(thisset)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
thisset = {"apple", "banana", "cherry", True, 1, 2}

print(thisset)

#True and 1 is considered the same value
# Out:
# {True, 2, 'apple', 'cherry', 'banana'}

# %% [markdown]
# ###Get the Length of a Set

# %%
thisset = {"apple", "banana", "cherry"}

print(len(thisset))
# Out:
# 3

# %% [markdown]
# ###Set Items - Data Types
#
# String, int and boolean data types

# %%
set1={"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}
print(set1)
print(set2)
print(set3)
# Out:
# {'apple', 'cherry', 'banana'}
# {1, 3, 5, 7, 9}
# {False, True}

# %% [markdown]
# ###Getting type

# %%
myset = {"apple", "banana", "cherry"}
print(type(myset))
# Out:
# <class 'set'>

# %% [markdown]
# ###The set() Constructor

# %%
thisset = set(("apple", "banana", "cherry"))
print(thisset)
# Out:
# {'cherry', 'apple', 'banana'}

# %% [markdown]
# ###Change Items
#
# Once a set is created, you cannot change its items, but you can add new items

# %% [markdown]
# ###Add Set Items

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("blueberry")

print(thisset)
# Out:
# {'blueberry', 'apple', 'cherry', 'banana'}

# %%
thisset = {"apple", "banana", "cherry"}
set2 = {"pineapple", "mango", "papaya"}

thisset.update(set2)

print(thisset)
# Out:
# {'mango', 'papaya', 'apple', 'pineapple', 'cherry', 'banana'}

# %% [markdown]
# ###Add Any Iterable

# %%
set = {"apple", "banana", "cherry"}
list = ["kiwi", "orange"]

set.update(list)

print(set)
# Out:
# {'kiwi', 'apple', 'orange', 'cherry', 'banana'}

# %% [markdown]
# ###Remove Item

# %%
thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.discard("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

x = thisset.pop()#lekin yeh koi random number remove kry ga phr

print(x)

print(thisset)
# Out:
# cherry
# {'banana', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.clear()

print(thisset)
# Out:
# set()

# %% [markdown]
# ###Loop Items

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# cherry
# banana
# apple

# %% [markdown]
# ###Join Sets
# There are several ways to join two or more sets in Python.
#
# The union() and update() methods joins all items from both sets.
#
# The intersection() method keeps ONLY the duplicates.
#
# The difference() method keeps the items from the first set that are not in the other set(s).
#
# The symmetric_difference() method keeps all items EXCEPT the duplicates.

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3)  #yeh isky sb elements ik mn krdy ga or ika operator hai "|"
# Out:
# {'b', 1, 2, 3, 'a', 'c'}

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set1.update(set2)
print(set1)  #union set2 ko set1 mm insert krdega

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.intersection(set2)
print(set3)  #sirf duplicates reh jayen gy

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)

print(set3) #set1 mn hai elements or set 2mn ni h

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)

print(set3)  #sirf wo jo dono mn ni present jo common ni hn
# Out:
# {'banana', 'cherry', 'microsoft', 'google'}

# %% [markdown]
# ###Python frozenset
# frozenset is an immutable version of a set.
#
# Like sets, it contains unique, unordered, unchangeable elements.
#
# Unlike sets, elements cannot be added or removed from a frozenset.

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'cherry', 'banana', 'apple'})
# <class 'frozenset'>

# %% [markdown]
# ##Python Dictionaries

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# ###Dictionary
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict["brand"]) #dupliate allow ni overwrite hojayen gy wo
# Out:
# Ford

# %% [markdown]
# ###Dictionary Length

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}
print(len(thisdict))
print(type(thisdict))
# Out:
# 4
# <class 'dict'>

# %% [markdown]
# ###Accessing Items

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict["model"]
x =  thisdict.get("model")
print(x)
y = thisdict.keys()
print(y)
z = thisdict.values()
print(z)
b = thisdict.items()
print(b)
# Out:
# Mustang
# dict_keys(['brand', 'model', 'year'])
# dict_values(['Ford', 'Mustang', 1964])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])

# %% [markdown]
# ###Change Dictionary Items

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["year"] = 2018
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2018}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"year": 2020})

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["color"] = "red"
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.popitem()  #last item pop kry gi
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict["model"]
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %% [markdown]
# ###Loop Dictionaries

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in thisdict:
  print(x) #keys hoi print

print("################")
for x in thisdict:
  print(thisdict[x]) #values print hongi keys ki

print("##############")

for x in thisdict.values():
  print(x)

print("##############")
for x in thisdict.keys():
  print(x)

print("################")

for x,y in thisdict.items():
  print(x,y)
# Out:
# brand
# model
# year
# ################
# Ford
# Mustang
# 1964
# ##############
# Ford
# Mustang
# 1964
# ##############
# brand
# model
# year
# ################
# brand Ford
# model Mustang
# year 1964

# %% [markdown]
# ### Copy Dictionaries

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict.copy()
print(mydict)
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# ### Nested Dictionaries

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(myfamily)
print(myfamily["child2"]["name"])

for x, obj in myfamily.items():
  print(x)

  for y in obj:
    print(y + ':', obj[y])
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}
# Tobias
# child1
# name: Emil
# year: 2004
# child2
# name: Tobias
# year: 2007
# child3
# name: Linus
# year: 2011
