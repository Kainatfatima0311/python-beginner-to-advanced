# %% [markdown]
# ###**List Comprehension**
#
# List comprehension offers a shorter syntax when you want to create a new list based on the values of an existing list.
#
# *newlist = [expression for item in iterable if condition == True]*

# %%
#without list comprehension
fruits=["apple","banana","cherry","orange","kiwi","dragonfruit"]
fruits_start_With_a=[]

for x in fruits:
  if "a" in x:
    fruits_start_With_a.append(x)
print(fruits_start_With_a)

#with list comprehension
newlist=[x for x in fruits if "e" in x]
print (newlist)
# Out:
# ['apple', 'banana', 'orange', 'dragonfruit']
# ['apple', 'cherry', 'orange']

# %% [markdown]
# ###**Python - Sort Lists**
#
# List objects have a sort() method that will sort the list alphanumerically, ascending, by default:

# %%
marks=[90,83,88,23,10]
marks.sort()
print(marks)
marks.sort(reverse=True)
print(marks)
# Out:
# [10, 23, 83, 88, 90]
# [90, 88, 83, 23, 10]

# %% [markdown]
# ###**Customize Sort Function**

# %%
def myfunc(n):
 return abs(n-50)
thislist=[100,50,65,82,32]
thislist.sort(key=myfunc)
print(thislist)

print("----------")


# fro reverse
fruits=["apple","Orange","Kiwi","dragonfruit"]
fruits.reverse()
print(fruits)
print("----------")


#fr lower character first arrangement
fruits.sort(key=str.lower)
print(fruits)
print("----------")


#for capital first
fruits.sort()
print(fruits)
# Out:
# [50, 65, 32, 82, 100]
# ----------
# ['dragonfruit', 'Kiwi', 'Orange', 'apple']
# ----------
# ['apple', 'dragonfruit', 'Kiwi', 'Orange']
# ----------
# ['Kiwi', 'Orange', 'apple', 'dragonfruit']

# %% [markdown]
# ###**Copy Lists**

# %%
list1=[100,38,450,45]
list2=list1.copy()
print(list2)
print(list1)

print("another way to copy entire list")

list3=list(list1)
print(list3)
# Out:
# [100, 38, 450, 45]
# [100, 38, 450, 45]
# another way to copy entire list
# [100, 38, 450, 45]

# %% [markdown]
# ###**Python Tuples**
#
# Tuples are used to store multiple items in a single variable.
#
# Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.
#
# A tuple is a collection which is ordered and unchangeable.
#
# Tuples are written with round brackets.

# %%
tuple=("apple","banana","orange")
print(tuple)
# Out:
# ('apple', 'banana', 'orange')

# %% [markdown]
# ###**Tuple Items**
#
# Tuple items are ordered, unchangeable, and allow duplicate values.
#
# Tuple items are indexed, the first item has index [0], the second item has index [1] etc.
#
#
# **Ordered**
# When we say that tuples are ordered, it means that the items have a defined order, and that order will not change.
#
# **Unchangeable**
# Tuples are unchangeable, meaning that we cannot change, add or remove items after the tuple has been created.
#
# **Allow Duplicates**

# %%
tuple=(100,100129,100,38)
print(tuple)
print(len(tuple))
# Out:
# (100, 100129, 100, 38)
# 4

# %%
tuple1=("apple",)
print(type(tuple1))


tuple2=("apple")
print(type(tuple2))
# Out:
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# ###**The tuple() Constructor**

# %%
tuple2=tuple(("apple","kiwi"))
print(type(tuple2))
# Out:
# <class 'tuple'>

# %% [markdown]
# ###**Python Collections (Arrays)**
#
# There are four collection data types in the Python programming language:
#
# **List** is a collection which is ordered and changeable. Allows duplicate members.
# **Tuple** is a collection which is ordered and unchangeable. Allows duplicate members.
# **Set** is a collection which is unordered, unchangeable, and unindexed. No duplicate members.
# **Dictionary** is a collection which is ordered and changeable. No duplicate members.

# %% [markdown]
# ###Access Tuple Items

# %%
tuple1=("kf","tayyab","abdullah","hamza")
print(tuple1[2])
# Out:
# abdullah

# %% [markdown]
# ###Range of Indexes

# %%
names=("sara","zara","ayesha","mishal")
print(names[1:3])
# Out:
# ('zara', 'ayesha')

# %% [markdown]
# ###Change Tuple Values
#
# Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.

# %%
#Convert the tuple into a list to be able to change it:
x=(12,23,45)
y=list(x)
y[1]="kiwi"
x=tuple(y)
print(x)
print(type(x))


#for every function you want to perform
#convert tuple into list then make change  then
#convert it back
# Out:
# (12, 'kiwi', 45)
# <class 'tuple'>

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)

#two tuples can be added
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
#remove from list
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)
print(thistuple)
# Out:
# ('banana', 'cherry')

# %% [markdown]
# ###Unpack Tuples
#
# When we create a tuple, we normally assign values to it. This is called "packing" a tuple
#
# But, in Python, we are also allowed to extract the values back into variables. This is called "unpacking"

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ###**Using Asterisk**
#
#
# If the number of variables is less than the number of values, you can add an * to the variable name and the values will be assigned to the variable as a list

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "berry")

(green, yellow, *red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'berry']

# %% [markdown]
# ###**Python - Loop Tuples**

# %%
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 1

# %% [markdown]
# ###Join Two Tuples
# To join two or more tuples you can use the + operator

# %%
tuple1=(1,2,3,4,5)
tuple2=(4,67,5,4)
tuple3 = tuple1+tuple2
print(tuple3)
# Out:
# (1, 2, 3, 4, 5, 4, 67, 5, 4)

# %%
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2

print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')
